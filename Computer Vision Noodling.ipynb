# %% [markdown]
# # 2016-12-19 (Monday)
#
# Let's work through chapter 1 of *Programming Computer Vision with Python.*

# %% [markdown]
# To start with, let's make sure this thing is on:

# %%
# Inline display of plots - cribbed from:
# https://nbviewer.jupyter.org/github/jrjohansson/scientific-python-lectures/blob/master/Lecture-4-Matplotlib.ipynb
# %matplotlib inline

from PIL import Image
from pathlib import Path

# Aim this at wherever you unzipped the pcv_data.zip downloaded from:
# http://programmingcomputervision.com/
PCV_DATA_DIR = Path.home() / 'Downloads' / 'pcv_data'
EMPIRE_JPG = PCV_DATA_DIR / 'empire.jpg'

# The example from page 1
some_image = Image.open(EMPIRE_JPG)

some_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=569x800 at 0x10D1988D0>

# %% [markdown]
# Neato! I see an image!
#
# What about the grayscale version?

# %%
Image.open(EMPIRE_JPG).convert('L')
# Out:
# <PIL.Image.Image image mode=L size=569x800 at 0x10D180E10>

# %%
# thumbnail() keeps returning None - what gives?
# thought at first the (128,128) was too big (the image itself is only 92x128), but, nope!
some_image.thumbnail((128, 128))

print(dir(some_image))
print(help(some_image.thumbnail))

# A-hah! It's destructively modifying it! That's why the image ended up with a max dimension of 128.
# Let's see that image:
some_image
# Out:
# ['_Image__transformer', '__class__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_copy', '_dump', '_expand', '_getexif', '_getmp', '_makeself', '_new', '_open', '_repr_png_', 'app', 'applist', 'bits', 'category', 'close', 'convert', 'copy', 'crop', 'decoderconfig', 'decodermaxblock', 'draft', 'effect_spread', 'encoderconfig', 'encoderinfo', 'filename', 'filter', 'format', 'format_description', 'fp', 'frombytes', 'fromstring', 'getbands', 'getbbox', 'getcolors', 'getdata', 'getextrema', 'getim', 'getpalette', 'getpixel', 'getprojection', 'height', 'histogram', 'huffman_ac', 'huffman_dc', 'icclist', 'im', 'info', 'layer', 'layers', 'load', '
# ...
